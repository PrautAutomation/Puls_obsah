# %% [markdown]
# # Kapitola 2: Buďte jasní a přímí
#
# - [Lekce](#lesson)
# - [Cvičení](#exercises)
# - [Experimentální playground](#example-playground)
#
# ## Nastavení
#
# Spusťte následující nastavovací buňku, která načte API klíč a vytvoří pomocnou funkci `get_completion`.

# %%
# Import python's built-in regular expression library
import re
import boto3
import json

# Import the hints module from the utils package
import os
import sys
module_path = ".."
sys.path.append(os.path.abspath(module_path))
from utils import hints

# Retrieve the MODEL_NAME variable from the IPython store
# %store -r MODEL_NAME
# %store -r AWS_REGION

client = boto3.client('bedrock-runtime',region_name=AWS_REGION)

def get_completion(prompt,system=''):
    body = json.dumps(
        {
            "anthropic_version": '',
            "max_tokens": 2000,
            "messages": [{"role": "user", "content": prompt}],
            "temperature": 0.0,
            "top_p": 1,
            "system": system
        }
    )
    response = client.invoke_model(body=body, modelId=MODEL_NAME)
    response_body = json.loads(response.get('body').read())

    return response_body.get('content')[0].get('text')

# %% [markdown]
# ---
#
# ## Lekce
#
# **Claude nejlépe reaguje na jasné a přímé instrukce.**
#
# Představte si Claude jako člověka, který je v práci nový. **Claude nemá žádný kontext** k tomu, co má dělat, kromě toho, co mu doslova řeknete. Stejně jako když poprvé zadáváte úkol člověku, čím přesněji a přímočařeji Claude vysvětlíte, co chcete, tím lepší a přesnější odpověď dostanete.
#
# Když si nejste jistí, držte se **zlatého pravidla jasného promptování**:
# - Ukažte prompt kolegovi nebo kamarádovi a nechte ho podle instrukcí postupovat, abyste viděli, jestli dokáže vytvořit výsledek, který chcete. Pokud je zmatený on, bude zmatený i Claude.

# %% [markdown]
# ### Příklady
#
# Vezměme si úkol jako psaní poezie. Ignorujte případné nesrovnalosti v počtu slabik; LLM zatím nejsou skvělé v počítání slabik.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Toto haiku je docela pěkné, ale uživatelé mohou chtít, aby Claude přešel rovnou k básni bez úvodu typu `Here is a haiku`.
#
# Jak toho dosáhneme? **Řekneme si o to.**

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Zde je další příklad. Zeptáme se Claude, kdo je nejlepší basketbalista všech dob. Níže vidíte, že Claude sice uvede několik jmen, ale **neodpoví jednoznačným `nejlepší`**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Můžeme Claude přimět, aby se rozhodl a vybral jednoho nejlepšího hráče? Ano. Stačí se zeptat přímo.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Pokud chcete experimentovat s prompty z lekce, aniž byste měnili obsah výše, sjeďte až na konec notebooku do části [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Cvičení
# - [Cvičení 2.1 - Španělština](#exercise-21---spanish)
# - [Cvičení 2.2 - Pouze jeden hráč](#exercise-22---one-player-only)
# - [Cvičení 2.3 - Napište příběh](#exercise-23---write-a-story)

# %% [markdown]
# ### Cvičení 2.1 - Španělština
# Upravte `SYSTEM_PROMPT` tak, aby Claude odpověděl španělsky.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "[Replace this text]"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ Pokud chcete nápovědu, spusťte buňku níže.

# %%
print(hints.exercise_2_1_hint)

# %% [markdown]
# ### Cvičení 2.2 - Pouze jeden hráč
#
# Upravte `PROMPT` tak, aby Claude vůbec nekličkoval a odpověděl **POUZE** jménem jednoho konkrétního hráče, **bez dalších slov nebo interpunkce**.

# %%
# Prompt - this is the only field you should change
PROMPT = "[Replace this text]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ Pokud chcete nápovědu, spusťte buňku níže.

# %%
print(hints.exercise_2_2_hint)

# %% [markdown]
# ### Cvičení 2.3 - Napište příběh
#
# Upravte `PROMPT` tak, aby Claude odpověděl co nejdelší odpovědí. Pokud bude odpověď **přes 800 slov**, bude vyhodnocena jako správná.

# %%
# Prompt - this is the only field you should change
PROMPT = "[Replace this text]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ Pokud chcete nápovědu, spusťte buňku níže.

# %%
print(hints.exercise_2_3_hint)

# %% [markdown]
# ### Gratulujeme!
#
# Pokud jste vyřešili všechna cvičení až sem, jste připraveni přejít na další kapitolu. Hodně zdaru s promptováním.

# %% [markdown]
# ---
#
# ## Example Playground
#
# Toto je prostor, kde můžete volně experimentovat s příklady promptů z této lekce a upravovat je, abyste viděli, jak se tím mění odpovědi Claude.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
